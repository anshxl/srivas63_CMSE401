# %%
import numpy as np
import cProfile
import pstats
import io

#Config
np.random.seed(42)

# %%
#Import NN class
from model_baseline import NeuralNetwork

# %% [markdown]
# ### Code Profiling

# %%
# # Load MNIST dataset
# from data_loader import load_data

# (X_train, y_train), (X_test, y_test) = load_data()

# # Create an instance of your network
# nn = NeuralNetwork(input_size=784, hidden_size=128, output_size=10)

# # Create a cProfile profiler instance
# profiler = cProfile.Profile()

# # Enable profiling for the training process
# profiler.enable()
# nn.train(X_train, y_train, learning_rate=0.001, epochs=10)
# profiler.disable()

# # Set up a StringIO stream to hold the profiling results
# s = io.StringIO()
# stats = pstats.Stats(profiler, stream=s).sort_stats('cumulative')

# # Option 1: Print complete stats for all functions
# stats.print_stats()

# # Option 2: Filter and print stats only for functions in your NeuralNetwork class
# # This assumes the functions have "NeuralNetwork" in their qualified name.
# # Uncomment the next line to filter:
# # stats.print_stats("model.py")

# # Print the profiling breakdown
# print(s.getvalue())

# %%
# Load MNIST dataset
from data_loader import load_data

(X_train, y_train), (X_test, y_test) = load_data()

# Create an instance of your network
nn = NeuralNetwork(input_size=784, hidden_size=128, output_size=10)

# Train the network
nn.train(X_train, y_train, learning_rate=0.001, epochs=40, verbose=False)

# %%
#Evaluate model
accuracy = nn.evaluate(X_test, y_test)
print(f'Accuracy: {accuracy:.2f}%')
# Out:
# Accuracy: 91.76%

# %%
#Plot model architecture
nn.plot_architecture(show_inline=True)

# %%
#Plot loss
nn.plot_loss(show_inline=True)
